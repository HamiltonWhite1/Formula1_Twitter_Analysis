# %%
import pandas as pd

# %%
first_JSON = pd.read_json('JSON_for_MysQL_Import/fourth_scrape_js.json')
second_JSON = pd.read_json('JSON_for_MysQL_Import/fifth_scrape.json')
third_JSON = pd.read_json('JSON_for_MysQL_Import/comp_scrape.json')

# %%
first_JSON
# Out:
#                                                  user                   id  \
# 0   {'id': 69008563, 'id_str': '69008563', 'name':...  1509358902420598784
# 1   {'id': 1101416096895250400, 'id_str': '1101416...  1509326512721481728
# 2   {'id': 69008563, 'id_str': '69008563', 'name':...  1509596890282618880
# 3   {'id': 32950000, 'id_str': '32950000', 'name':...  1509471020503216128
# 4   {'id': 353786894, 'id_str': '353786894', 'name...  1509463545565650944
# ..                                                ...                  ...
# 68  {'id': 26235265, 'id_str': '26235265', 'name':...  1065606780410056704
# 69  {'id': 118985797, 'id_str': '118985797', 'name...  1509492095278481408
# 70  {'id': 1499609706209419300, 'id_str': '1499609...  1509521721270882304
# 71  {'id': 1475480210489454600, 'id_str': '1475480...  1509485782649741312
# 72  {'id': 312437482, 'id_str': '312437482', 'name...  1509480367711219712
#
# ...
